# %% [markdown]
# ### 1. Importing Images dataset

# %% [markdown]
# #### About the dataset:
#
# This dataset comprises images generated by artificial intelligence (AI) and real art with respective labels. The primary objective of this project is to construct a model capable of detecting AI-generated images.
#
# **URL:** https://huggingface.co/datasets/Hemg/AI-Generated-vs-Real-Images-Datasets

# %%
# Make sure to run the following command in terminal to install library 'datasets'
##  pip install datasets

# Import necessary libraries
from datasets import load_dataset
import pandas as pd

# %%
# Import dataset
image_ds = load_dataset("Hemg/AI-Generated-vs-Real-Images-Datasets")
print(image_ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 152710
#     })
# })

# %% [markdown]
# ### 2. Importing Speech dataset

# %% [markdown]
# #### About the dataset:
#
# This dataset comprises speech samples generated by various artists with different emotions. The primary objective of this problem is to train a model which is capable of detecting the emotion of a unseen speech sample.
#
# **Dataset URL:** https://huggingface.co/datasets/stapesai/ssi-speech-emotion-recognition

# %%
# Import Dataset
speech_ds = load_dataset("stapesai/ssi-speech-emotion-recognition")
print(speech_ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file_path', 'emotion', 'emotion_intensity', 'gender', 'age_group', 'dataset', 'speaker_id', 'text', 'utterance_number'],
#         num_rows: 10000
#     })
#     validation: Dataset({
#         features: ['file_path', 'emotion', 'emotion_intensity', 'gender', 'age_group', 'dataset', 'speaker_id', 'text', 'utterance_number'],
#         num_rows: 1999
#     })
#     test: Dataset({
#         features: ['file_path', 'emotion', 'emotion_intensity', 'gender', 'age_group', 'dataset', 'speaker_id', 'text', 'utterance_number'],
#         num_rows: 163
#     })
# })

# %% [markdown]
# ### 3. Importing Text dataset

# %% [markdown]
# #### About the dataset:
#
# To develop a model capable of analyzing and classifying sentiments expressed in mental health-related textual data.
#
# **Dataset URL:** https://www.kaggle.com/datasets/suchintikasarkar/sentiment-analysis-for-mental-health/data

# %%
text_ds = pd.read_csv("CombinedData.csv")
text_ds.head()
# Out:
#    Unnamed: 0                                          statement   status
# 0           0                                         oh my gosh  Anxiety
# 1           1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2           2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3           3  I've shifted my focus to something else but I'...  Anxiety
# 4           4  I'm restless and restless, it's been a month n...  Anxiety

# %%
import torch

# Check if GPU is available
print(torch.cuda.is_available())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       3 # Check if GPU is available
#       4 print(torch.cuda.is_available())
#
# ModuleNotFoundError: No module named 'torch'
